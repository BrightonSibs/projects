# %% [markdown]
# <a href="https://colab.research.google.com/github/BrightonSibs/projects/blob/main/wifi_health_monitor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python /content/wifi-health-monitor/generate_sample_data.py
# Out:
# Generating simulated Wi-Fi CSI dataset...
#   Generating 50 samples for 'slow' gait...
#   Generating 50 samples for 'normal' gait...
#   Generating 50 samples for 'fast' gait...
#
# ✓ Generated 142800 total data points
#   Samples per class: 50
#   Classes: slow, normal, fast
#
# ✓ Dataset saved as 'wifi_csi_data.csv'
#
# First few rows:
#    timestamp  csi_amplitude_1  csi_amplitude_2  ...  age_group     sex height_cm
# 0   0.000000         0.221197         0.338378  ...     middle  female       188
# 1   0.010013        -0.324846         0.022570  ...     middle  female       188
# 2   0.020025        -0.293502         0.616786  ...     middle  female       188
# 3   0.030038         0.222679         1.184468  ...     middle  female       188
# 4   0.040050        -0.172455         0.542423  ...     middle  female       188
# 5   0.050063         0.519895         0.788244  ...     middle  female       188
# ...

# %%
# !python /content/wifi-health-monitor/wifi_monitor.py
# Out:
# Loading Wi-Fi CSI data...
#
# ✓ Loaded 142800 data points
#   Unique samples: 150
#
# Data columns:
# ['timestamp', 'csi_amplitude_1', 'csi_amplitude_2', 'csi_amplitude_3', 'gait_speed', 'sample_id', 'age_group', 'sex', 'height_cm']
#
# First few rows:
#    timestamp  csi_amplitude_1  csi_amplitude_2  ...  age_group     sex height_cm
# 0   0.000000         0.221197         0.338378  ...     middle  female       188
# 1   0.010013        -0.324846         0.022570  ...     middle  female       188
# 2   0.020025        -0.293502         0.616786  ...     middle  female       188
# 3   0.030038         0.222679         1.184468  ...     middle  female       188
# 4   0.040050        -0.172455         0.542423  ...     middle  female       188
#
# [5 rows x 9 columns]
#
# Gait speed distribution:
# gait_speed
# fast      50
# normal    50
# slow      50
# Name: sample_id, dtype: int64
#
# Demographic breakdown:
#
# By age group:
# age_group
# elderly    44
# middle     60
# ...

# %%
# !python /content/wifi-health-monitor/feature_extraction.py
# Out:
# Extracting features from all samples...
#   Processed 20/150 samples...
#   Processed 40/150 samples...
#   Processed 60/150 samples...
#   Processed 80/150 samples...
#   Processed 100/150 samples...
#   Processed 120/150 samples...
#   Processed 140/150 samples...
#
# ✓ Extracted features from 150 samples
#   Total features per sample: 48
#
# ✓ Features saved as 'wifi_features.csv'
#
# Sample features (first 5 columns):
#    csi_amplitude_1_mean  ...  csi_amplitude_1_min
# 0              0.015866  ...            -1.743760
# 1              0.026161  ...            -1.478201
# 2             -0.003620  ...            -1.749834
# 3              0.015479  ...            -1.540479
# 4              0.022496  ...            -1.763817
#
# [5 rows x 5 columns]
#
# Feature statistics:
#        csi_amplitude_1_mean  ...   height_cm
# count            150.000000  ...  150.000000
# mean               0.011872  ...  168.773333
# std                0.014455  ...   12.064228
# ...

# %%
# !python /content/wifi-health-monitor/wifi_monitor.py
# Out:
# ...
# WI-FI BASED GAIT DETECTION SYSTEM
# ...
#
# Loading feature data...
#
# ✓ Loaded data:
#   Samples: 150
#   Features: 48
#   Classes: ['slow' 'normal' 'fast']
#
# Data split:
#   Training samples: 105
#   Test samples: 45
#
# Training model...
# ✓ Model trained
#
# Evaluating model...
#
# ...
# OVERALL PERFORMANCE
# ...
# Accuracy: 1.000
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#         fast       1.00      1.00      1.00        15
#       normal       1.00      1.00      1.00        15
#         slow       1.00      1.00      1.00        15
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# Generating confusion matrix...
# ✓ Saved confusion_matrix.png
# Figure(800x600)
#
# Analyzing feature importance...
# ✓ Saved feature_importance.png
# Figure(1000x600)
#
# ...
# ✓ ANALYSIS COMPLETE
# ...
#
# Generated files:
# ...

# %%
# !python /content/wifi-health-monitor/fairness_analysis.py
# Out:
# ...
# WI-FI GAIT DETECTION - FAIRNESS ANALYSIS
# ...
#
# Loading data for fairness analysis...
#
# ✓ Loaded 45 test samples with demographics
#
# ...
# FAIRNESS CHECK: AGE GROUP
# ...
#
# middle         :
#   Samples: 18
#   Accuracy: 1.000
#   Precision: 1.000
#   Recall: 1.000
#   F1-Score: 1.000
#
# elderly        :
#   Samples: 17
#   Accuracy: 1.000
#   Precision: 1.000
#   Recall: 1.000
#   F1-Score: 1.000
#
# young          :
#   Samples: 10
#   Accuracy: 1.000
#   Precision: 1.000
#   Recall: 1.000
#   F1-Score: 1.000
#
# ──────────────────────────────────────────────────────────────────────
# Accuracy Disparity: 0.000
# ✓ Disparity within acceptable range (0.05)
#   System appears FAIR across Age Group
#
# ...
# FAIRNESS CHECK: SEX
# ...
#
# female         :
#   Samples: 25
#   Accuracy: 1.000
#   Precision: 1.000
#   Recall: 1.000
#   F1-Score: 1.000
#
# male           :
#   Samples: 20
#   Accuracy: 1.000
#   Precision: 1.000
#   Recall: 1.000
#   F1-Score: 1.000
#
# ...

# %%
# !python /content/wifi-health-monitor/create_dashboard.py
# Out:
# Creating comprehensive dashboard...
# ✓ Saved comprehensive_dashboard.png
# Figure(1600x1000)

# %%
# !python /content/wifi-health-monitor/wifi_gait_monitor.py
# Out:
# ...
# WI-FI GAIT MONITORING SYSTEM
# ...
#
# Loading data...
# ✓ Loaded 142800 data points
# Extracting features...
#   Progress: 25/150
#   Progress: 50/150
#   Progress: 75/150
#   Progress: 100/150
#   Progress: 125/150
#   Progress: 150/150
# ✓ Extracted features from 150 samples
#
# Preparing training data...
# ✓ Training samples: 105
# ✓ Test samples: 45
#
# Training gait classifier...
# ✓ Model trained
#
# ...
# MODEL EVALUATION
# ...
#
# Model Performance:
#   Accuracy: 1.000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         fast       1.00      1.00      1.00        15
#       normal       1.00      1.00      1.00        15
#         slow       1.00      1.00      1.00        15
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
# ✓ Saved confusion_matrix.png
# ✓ Saved feature_importance.png
#
# ...
# FAIRNESS ANALYSIS
# ...
#
# ...
