# %% [markdown]
# <a href="https://colab.research.google.com/github/BrightonSibs/projects/blob/main/Health_equity_monitor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cd /content/health-equity-monitor

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/monitor.py
# Out:
# Clean data: 30162 rows
# Positive outcomes (>50K): 7508
# Negative outcomes (<=50K): 22654
#
# Overall model accuracy: 0.800
#
# Fairness Check by Sex:
# Male accuracy: 0.770
# Female accuracy: 0.862
# Accuracy difference: 0.092
#  WARNING: Model shows potential BIAS between sexes!
#
# --- Detailed Breakdown ---
# Male test samples: 6138
# Female test samples: 2911
#
# Male positive prediction rate: 0.215
# Female positive prediction rate: 0.115
#
# ...
# Fairness Check by Race:
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Maximum accuracy difference across races: 0.090
#  WARNING: Model shows potential BIAS across races!
#
# Generating visualization...
#  Visualization saved as 'equity_report.png'
# Figure(1200x500)
#
# Saving results to file...
#  Report saved as 'equity_report.txt'
#
# ...
# TIME-BASED DRIFT DETECTION
# ...
#
# Period 1:
# ...

# %%
# !python /content/health-equity-monitor/equity_monitor_clean.py
# Out:
# ...
# REAL-TIME HEALTH EQUITY DRIFT MONITOR
# ...
#
# Loading data...
# ✓ Loaded 30162 rows
#
# Training model...
# ✓ Model trained. Overall accuracy: 0.800
#
# ...
# FAIRNESS CHECK: SEX
# ...
# Male accuracy:   0.770 (n=6138)
# Female accuracy: 0.862 (n=2911)
# Disparity:       0.092
# ⚠️  BIAS DETECTED
#
# ...
# FAIRNESS CHECK: RACE
# ...
# White               : 0.790 (n=7797)
# Asian-Pac-Islander  : 0.792 (n=259)
# Black               : 0.880 (n=861)
# Amer-Indian-Eskimo  : 0.868 (n=76)
# Other               : 0.804 (n=56)
#
# Max disparity: 0.090
# ⚠️  BIAS DETECTED
#
# ...
# TEMPORAL DRIFT DETECTION
# ...
# Period 1: Disparity=0.112 ⚠️  BIAS
# Period 2: Disparity=0.093 ⚠️  BIAS
# Period 3: Disparity=0.060 ⚠️  BIAS
# Period 4: Disparity=0.102 ⚠️  BIAS
#
# ...
# ALERT SUMMARY
# ...
#
# 🚨 3 ALERT(S) DETECTED:
#
# 🟡 Alert 1: Sex Disparity
#    Severity: MEDIUM
#    Value: 0.092
# 🟡 Alert 2: Race Disparity
#    Severity: MEDIUM
#    Value: 0.090
# 🔴 Alert 3: Temporal Drift
#    Severity: HIGH
#    Value: 4.000
#
# ...
